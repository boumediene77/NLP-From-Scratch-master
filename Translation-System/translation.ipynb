# %%
import logging
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
import torch
import unicodedata
import string
from tqdm import tqdm
from pathlib import Path
from typing import List
import datetime
import time
import re
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F
import random

# %%
logging.basicConfig(level=logging.INFO)

FILE = "en-fra.txt"

writer = SummaryWriter("runs/translation"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

def normalize(s):
    return re.sub(' +',' ', "".join(c if c in string.ascii_letters else " "
         for c in unicodedata.normalize('NFD', s.lower().strip())
         if  c in string.ascii_letters+" "+string.punctuation)).strip()

# %%
class Vocabulary:
    """Permet de gérer un vocabulaire.

    En test, il est possible qu'un mot ne soit pas dans le
    vocabulaire : dans ce cas le token "__OOV__" est utilisé.
    Attention : il faut tenir compte de cela lors de l'apprentissage !

    Utilisation:

    - en train, utiliser v.get("blah", adding=True) pour que le mot soit ajouté
      automatiquement
    - en test, utiliser v["blah"] pour récupérer l'ID du mot (ou l'ID de OOV)
    """
    PAD = 0
    EOS = 1
    SOS = 2
    OOVID = 3

    def __init__(self, oov: bool):
        self.oov = oov
        self.id2word = ["PAD", "EOS", "SOS"]
        self.word2id = {"PAD": Vocabulary.PAD, "EOS": Vocabulary.EOS, "SOS": Vocabulary.SOS}
        if oov:
            self.word2id["__OOV__"] = Vocabulary.OOVID
            self.id2word.append("__OOV__")

    def __getitem__(self, word: str):
        if self.oov:
            return self.word2id.get(word, Vocabulary.OOVID)
        return self.word2id[word]

    def get(self, word: str, adding=True):
        try:
            return self.word2id[word]
        except KeyError:
            if adding:
                wordid = len(self.id2word)
                self.word2id[word] = wordid
                self.id2word.append(word)
                return wordid
            if self.oov:
                return Vocabulary.OOVID
            raise

    def __len__(self):
        return len(self.id2word)

    def getword(self, idx: int):
        if idx < len(self):
            return self.id2word[idx]
        return None

    def getwords(self, idx: List[int]):
        return [self.getword(i) for i in idx]

# %%
class TradDataset():
    def __init__(self,data,vocOrig,vocDest,adding=True,max_len=10):
        self.sentences =[]
        for s in tqdm(data.split("\n")):
            if len(s)<1:continue
            orig,dest=map(normalize,s.split("\t")[:2])
            if len(orig)>max_len: continue
            self.sentences.append((torch.tensor([vocOrig.get(o) for o in orig.split(" ")]+[Vocabulary.EOS]),torch.tensor([vocDest.get(o) for o in dest.split(" ")]+[Vocabulary.EOS])))
    def __len__(self):return len(self.sentences)
    def __getitem__(self,i): return self.sentences[i]

# %%
def collate(batch):
    orig,dest = zip(*batch)
    o_len = torch.tensor([len(o) for o in orig])
    d_len = torch.tensor([len(d) for d in dest])
    return pad_sequence(orig),o_len,pad_sequence(dest),d_len

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
with open(FILE) as f:
    lines = f.readlines()

lines = [lines[x] for x in torch.randperm(len(lines))]
idxTrain = int(0.8*len(lines))

vocEng = Vocabulary(True)
vocFra = Vocabulary(True)
MAX_LEN=25
BATCH_SIZE=64

datatrain = TradDataset("".join(lines[:idxTrain]),vocEng,vocFra,max_len=MAX_LEN)
datatest = TradDataset("".join(lines[idxTrain:]),vocEng,vocFra,max_len=MAX_LEN)

train_loader = DataLoader(datatrain, collate_fn=collate, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(datatest, collate_fn=collate, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# 100%|██████████| 136521/136521 [00:07<00:00, 17268.85it/s]
# 100%|██████████| 34132/34132 [00:02<00:00, 16250.18it/s]

# %%
HIDDEN_SIZE = 128
INPUT_SIZE = len(vocEng)
OUTPUT_SIZE = len(vocFra)

# %%
class State:
    def __init__(self, encoder, decoder, optim_enc, optim_dec):
        self.encoder = encoder
        self.decoder = decoder
        self.optimizer_enc = optim_enc
        self.optimizer_dec = optim_dec
        self.epoch, self.iteration = 0, 0

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(Encoder, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, dropout=0.2)

    def forward(self, input):
        embedded = self.embedding(input)
        output = embedded
        
        _, hidden = self.gru(output)
        return hidden

# %%
class Decoder(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(Decoder, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input)
        output, hidden = self.gru(output, hidden)
        output = self.out(output)
        return output, hidden

# %%
def train_loop(dataloader,state,L):
    train_loss = 0
    for batch, (X, X_sizes, y, y_sizes) in enumerate(dataloader):
        
        X = X.to(device)
        y = y.to(device)
        
        
        input_length = X.size(0)
        target_length = y.size(0)
        
        loss = 0
        context = state.encoder(X)

        decoder_input = torch.ones(1, X.size(1), dtype=torch.long, device=device) * 2 # 2 is the SOS Token
        decoder_hidden = context

        teacher_forcing = True if random.random() < 0.5 else False
        decoder_outputs = []
        if teacher_forcing:
            for di in range(target_length):
                decoder_output, decoder_hidden = state.decoder(decoder_input, decoder_hidden)
                
                decoder_output = decoder_output.view(decoder_output.shape[1], -1)
                #loss += L(decoder_output, y[di])
                decoder_outputs.append(decoder_output)
                decoder_input = y[di].view(1, -1) 
        else:
            for di in range(target_length):
                decoder_output, decoder_hidden = state.decoder(decoder_input, decoder_hidden)
                decoder_output = decoder_output.view(decoder_output.shape[1], -1)
                _, pred = torch.max(decoder_output, 1)
                pred = pred.view(1, -1)
                decoder_input = pred 
                #loss += L(decoder_output, y[di])
                decoder_outputs.append(decoder_output)

        decoder_outputs = torch.stack(decoder_outputs).permute(0, 2, 1)
        #print(decoder_outputs.shape, y.shape)
        loss += L(decoder_outputs, y)
        train_loss += loss
        
        state.optimizer_enc.zero_grad()
        state.optimizer_dec.zero_grad()
        loss.backward()
        state.optimizer_enc.step()
        state.optimizer_dec.step() 
        
    train_loss = train_loss / len(dataloader)
    return train_loss.item()

# %%
def test_loop(dataloader,state,L):
    with torch.no_grad():
        test_loss = 0
        for batch, (X, X_sizes, y, y_sizes) in enumerate(dataloader):
            
            X = X.to(device)
            y = y.to(device)
            
            
            input_length = X.size(0)
            target_length = y.size(0)
            
            loss = 0
            context = state.encoder(X)

            decoder_input = torch.ones(1, X.size(1), dtype=torch.long, device=device) * 2 # 2 is the SOS Token
            decoder_hidden = context
            decoder_outputs = []
            for di in range(target_length):
                decoder_output, decoder_hidden = state.decoder(decoder_input, decoder_hidden)
                decoder_output = decoder_output.view(decoder_output.shape[1], -1)
                _, pred = torch.max(decoder_output, 1)

                pred = pred.view(1, -1)
                decoder_input = pred 
                decoder_outputs.append(decoder_output)
                #loss += L(decoder_output, y[di])

            decoder_outputs = torch.stack(decoder_outputs).permute(0, 2, 1)
            loss += L(decoder_outputs, y)
            test_loss += loss
            
        test_loss = test_loss / len(dataloader)
        return test_loss.item()

# %%
def train(train_loader, save_path, tensorboard_name, iterations=500):
    if save_path.is_file():
        with save_path.open('rb') as fp:
            state = torch.load(fp, map_location=torch.device(device))
    else :
        enc = Encoder(INPUT_SIZE, HIDDEN_SIZE).to(device)
        dec = Decoder(HIDDEN_SIZE, OUTPUT_SIZE).to(device)
        optimizer_enc = torch.optim.Adam(enc.parameters(), lr=0.001)
        optimizer_dec = torch.optim.Adam(dec.parameters(), lr=0.001)
        state = State(enc, dec, optimizer_enc, optimizer_dec)
    for epoch in range(state.epoch, iterations):
        loss_train = train_loop(train_loader, state, nn.CrossEntropyLoss())
        loss_test = test_loop(test_loader, state, nn.CrossEntropyLoss())
        with save_path.open("wb") as fp:
            state.epoch = epoch + 1
            torch.save(state, fp)
        writer.add_scalar(tensorboard_name+'/train', loss_train, epoch)
        writer.add_scalar(tensorboard_name+'/test', loss_test, epoch)
        print('Epoch: ', epoch, 'Loss train: ',loss_train, 'Loss test: ',loss_test)
    print("Done!")
    return state.encoder, state.decoder

# %%
savepath = Path('./translator.pt')
writer = SummaryWriter("runs/translation"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
encoder, decoder = train(train_loader, savepath, "Translator", iterations=100)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Epoch:  0 Loss train:  3.1588613986968994 Loss test:  2.9086570739746094
# Epoch:  1 Loss train:  2.4001834392547607 Loss test:  2.5697052478790283
# Epoch:  2 Loss train:  2.109360694885254 Loss test:  2.3991622924804688
# Epoch:  3 Loss train:  1.9176486730575562 Loss test:  2.288010835647583
# Epoch:  4 Loss train:  1.7861284017562866 Loss test:  2.2357337474823
# Epoch:  5 Loss train:  1.647982120513916 Loss test:  2.129486560821533
# Epoch:  6 Loss train:  1.5493524074554443 Loss test:  2.087124824523926
# Epoch:  7 Loss train:  1.441180944442749 Loss test:  2.054039478302002
# Epoch:  8 Loss train:  1.3809266090393066 Loss test:  2.008286237716675
# Epoch:  9 Loss train:  1.3110584020614624 Loss test:  1.9941905736923218
# Epoch:  10 Loss train:  1.2271981239318848 Loss test:  1.9792379140853882
# Epoch:  11 Loss train:  1.1762254238128662 Loss test:  1.9384344816207886
# Epoch:  12 Loss train:  1.129822850227356 Loss test:  1.9455541372299194
# Epoch:  13 Loss train:  1.0700902938842773 Loss test:  1.9381723403930664
# Epoch:  14 Loss train:  1.0460188388824463 Loss test:  1.9278899431228638
# Epoch:  15 Loss train:  1.0046898126602173 Loss test:  1.929437518119812
# Epoch:  16 Loss train:  0.9524216651916504 Loss test:  1.9226430654525757
# Epoch:  17 Loss train:  0.9369800686836243 Loss test:  1.9152162075042725
# Epoch:  18 Loss train:  0.8884155750274658 Loss test:  1.9272516965866089
# Epoch:  19 Loss train:  0.8753243088722229 Loss test:  1.9111367464065552
# Epoch:  20 Loss train:  0.833742618560791 Loss test:  1.9250097274780273
# Epoch:  21 Loss train:  0.8363950848579407 Loss test:  1.9212793111801147
# Epoch:  22 Loss train:  0.8156647086143494 Loss test:  1.9301780462265015
# Epoch:  23 Loss train:  0.8056164979934692 Loss test:  1.9185140132904053
# Epoch:  24 Loss train:  0.7757441997528076 Loss test:  1.9212255477905273
# Epoch:  25 Loss train:  0.7654005289077759 Loss test:  1.9182994365692139
# Epoch:  26 Loss train:  0.7362346053123474 Loss test:  1.9453818798065186
# Epoch:  27 Loss train:  0.739529550075531 Loss test:  1.9433954954147339
# Epoch:  28 Loss train:  0.7158249616622925 Loss test:  1.9356287717819214
# Epoch:  29 Loss train:  0.692327082157135 Loss test:  1.9588282108306885
# Epoch:  30 Loss train:  0.6772613525390625 Loss test:  1.970468282699585
# Epoch:  31 Loss train:  0.6828547120094299 Loss test:  1.9829542636871338
# Epoch:  32 Loss train:  0.672450602054596 Loss test:  1.9630873203277588
# Epoch:  33 Loss train:  0.6498557329177856 Loss test:  2.000223398208618
# Epoch:  34 Loss train:  0.6413662433624268 Loss test:  1.973670482635498
# Epoch:  35 Loss train:  0.6294301152229309 Loss test:  2.0015828609466553
# Epoch:  36 Loss train:  0.6254715919494629 Loss test:  1.9870871305465698
# Epoch:  37 Loss train:  0.6084074974060059 Loss test:  2.021292209625244
# Epoch:  38 Loss train:  0.6041267514228821 Loss test:  2.023369312286377
# Epoch:  39 Loss train:  0.5949751138687134 Loss test:  2.0138611793518066
# Epoch:  40 Loss train:  0.5885766744613647 Loss test:  2.0312795639038086
# Epoch:  41 Loss train:  0.5776358246803284 Loss test:  2.0503289699554443
# Epoch:  42 Loss train:  0.5728841423988342 Loss test:  2.039431571960449
# Epoch:  43 Loss train:  0.5705239176750183 Loss test:  2.0545549392700195
# Epoch:  44 Loss train:  0.5495708584785461 Loss test:  2.065953016281128
# Epoch:  45 Loss train:  0.5636991858482361 Loss test:  2.046212911605835
# Epoch:  46 Loss train:  0.5532107949256897 Loss test:  2.069371223449707
# Epoch:  47 Loss train:  0.55403071641922 Loss test:  2.0671536922454834
# Epoch:  48 Loss train:  0.5311723947525024 Loss test:  2.075698137283325
# Epoch:  49 Loss train:  0.5425149202346802 Loss test:  2.092820405960083
# Epoch:  50 Loss train:  0.5428405404090881 Loss test:  2.0914251804351807
# Epoch:  51 Loss train:  0.5102110505104065 Loss test:  2.0799765586853027
# Epoch:  52 Loss train:  0.5146801471710205 Loss test:  2.122135639190674
# Epoch:  53 Loss train:  0.5097975730895996 Loss test:  2.1020655632019043
# Epoch:  54 Loss train:  0.5202625393867493 Loss test:  2.10841965675354
# Epoch:  55 Loss train:  0.5052453875541687 Loss test:  2.122840642929077
# Epoch:  56 Loss train:  0.5042117834091187 Loss test:  2.1154637336730957
# Epoch:  57 Loss train:  0.4918992221355438 Loss test:  2.127861738204956
# Epoch:  58 Loss train:  0.49728092551231384 Loss test:  2.1197030544281006
# Epoch:  59 Loss train:  0.4876425564289093 Loss test:  2.129448413848877
# Epoch:  60 Loss train:  0.4803168475627899 Loss test:  2.1375324726104736
# Epoch:  61 Loss train:  0.4812954068183899 Loss test:  2.1466991901397705
# Epoch:  62 Loss train:  0.469793438911438 Loss test:  2.171224594116211
# Epoch:  63 Loss train:  0.47819218039512634 Loss test:  2.160590648651123
# Epoch:  64 Loss train:  0.47762608528137207 Loss test:  2.165673017501831
# Epoch:  65 Loss train:  0.46496275067329407 Loss test:  2.1894702911376953
# Epoch:  66 Loss train:  0.47215259075164795 Loss test:  2.197709560394287
# Epoch:  67 Loss train:  0.4627874195575714 Loss test:  2.2021422386169434
# Epoch:  68 Loss train:  0.46550408005714417 Loss test:  2.179941415786743
# Epoch:  69 Loss train:  0.4617922604084015 Loss test:  2.186547040939331
# Epoch:  70 Loss train:  0.454395055770874 Loss test:  2.2003068923950195
# Epoch:  71 Loss train:  0.45858708024024963 Loss test:  2.1969680786132812
# Epoch:  72 Loss train:  0.44108566641807556 Loss test:  2.2174172401428223
# Epoch:  73 Loss train:  0.44730761647224426 Loss test:  2.202594518661499
# Epoch:  74 Loss train:  0.44146299362182617 Loss test:  2.207308530807495
# Epoch:  75 Loss train:  0.4444398283958435 Loss test:  2.2324275970458984
# Epoch:  76 Loss train:  0.43929123878479004 Loss test:  2.217393636703491
# Epoch:  77 Loss train:  0.43952271342277527 Loss test:  2.238018751144409
# Epoch:  78 Loss train:  0.4396682679653168 Loss test:  2.2248992919921875
# Epoch:  79 Loss train:  0.4280916750431061 Loss test:  2.2427380084991455
# Epoch:  80 Loss train:  0.4311451017856598 Loss test:  2.2459914684295654
# Epoch:  81 Loss train:  0.42246201634407043 Loss test:  2.2755258083343506
# Epoch:  82 Loss train:  0.42804452776908875 Loss test:  2.260270595550537
# Epoch:  83 Loss train:  0.4187774956226349 Loss test:  2.2826857566833496
# Epoch:  84 Loss train:  0.4140957295894623 Loss test:  2.2858290672302246
# Epoch:  85 Loss train:  0.40991026163101196 Loss test:  2.288928508758545
# Epoch:  86 Loss train:  0.40334731340408325 Loss test:  2.2793045043945312
# Epoch:  87 Loss train:  0.4076097309589386 Loss test:  2.2816433906555176
# Epoch:  88 Loss train:  0.41066208481788635 Loss test:  2.301677703857422
# Epoch:  89 Loss train:  0.40649667382240295 Loss test:  2.3109781742095947
# Epoch:  90 Loss train:  0.4039759635925293 Loss test:  2.296783924102783
# Epoch:  91 Loss train:  0.4023749828338623 Loss test:  2.3163421154022217
# Epoch:  92 Loss train:  0.3962181508541107 Loss test:  2.3143582344055176
# Epoch:  93 Loss train:  0.40169593691825867 Loss test:  2.3109354972839355
# Epoch:  94 Loss train:  0.4083362817764282 Loss test:  2.296835422515869
# Epoch:  95 Loss train:  0.4079403877258301 Loss test:  2.306150197982788
# Epoch:  96 Loss train:  0.3999277353286743 Loss test:  2.3284924030303955
# Epoch:  97 Loss train:  0.3886438310146332 Loss test:  2.3273537158966064
# Epoch:  98 Loss train:  0.39473679661750793 Loss test:  2.325338363647461
# Epoch:  99 Loss train:  0.3915548324584961 Loss test:  2.3468573093414307
# Done!

# %%
# On affiche la traduction de la première phrase des 20 premier batch des  
# données de test à titre d'exemple.
c = 0
with torch.no_grad():
    for batch, (X, X_sizes, y, y_sizes) in enumerate(test_loader):
        c += 1
        if c == 20:
            pass 
        X = X.to(device)
        y = y.to(device)

        X = X[:, 0:1]
        y = y[:, 0:1]
        
        preds = []
        input_length = X.size(0)

        loss = 0
        context = encoder(X)

        pred = torch.ones(1, X.size(1), dtype=torch.long, device=device) * 2
        decoder_hidden = context

        while pred.item() != 1: #EOS = 1
            decoder_output, decoder_hidden = decoder(pred, decoder_hidden)
            decoder_output = decoder_output.view(decoder_output.shape[1], -1)
            _, pred = torch.max(decoder_output, 1)
            preds.append(pred.item())  
            pred = pred.view(1, -1)
        
        wds = vocEng.getwords(X)
        trs = vocFra.getwords(y)
        predtrs = vocFra.getwords(preds)
        print('c=',c)
        print('Anglais   : ', ' '.join(wds[:wds.index('EOS')]))
        print('Français  : ',' '.join(trs[:trs.index('EOS')]))
        print('Traduction: ',' '.join(predtrs[:predtrs.index('EOS')]))
        print('\n')
# Out:
# c= 1
# Anglais   :  the post office is closed
# Français  :  la poste est fermee
# Traduction:  la foule est ferme
#
#
# c= 2
# Anglais   :  my throat s a little dry
# Français  :  j ai la gorge un peu seche
# Traduction:  mon tient un peu soutien
#
#
# c= 3
# Anglais   :  i felt scared
# Français  :  je me sentis apeuree
# Traduction:  je me suis sentis apeuree
#
#
# c= 4
# Anglais   :  that s saturn
# Français  :  c est saturne
# Traduction:  c est
#
#
# c= 5
# Anglais   :  he asked me to
# Français  :  il me l a demande
# Traduction:  il m a demande
#
#
# c= 6
# Anglais   :  send the kids to bed
# Français  :  envoie les gosses au lit
# Traduction:  envoyez les gosses au lit
#
#
# c= 7
# Anglais   :  everyone was hurt
# Français  :  tout le monde fut blesse
# Traduction:  tout le monde fut blesse
#
#
# c= 8
# Anglais   :  have a nice trip
# Français  :  faites un bon voyage
# Traduction:  bon voyage
#
#
# c= 9
# Anglais   :  please let me stay
# Français  :  laissez moi rester s il vous plait
# Traduction:  laisse moi rester s il te plait
#
#
# c= 10
# Anglais   :  he comes from geneva
# Français  :  il vient de geneve
# Traduction:  il vient de hangzhou
#
#
# c= 11
# Anglais   :  i started crying
# Français  :  je me suis mis a pleurer
# Traduction:  je ai commence a pleurer
#
#
# c= 12
# Anglais   :  what was tom s last name
# Français  :  cetait quoi deja le nom de famille de tom
# Traduction:  quel etait le il a l il apprecie
#
#
# c= 13
# Anglais   :  where s the doctor
# Français  :  ou est le docteur
# Traduction:  ou est trouve
#
#
# c= 14
# Anglais   :  i may try again later
# Français  :  il se peut que j essaye a nouveau plus tard
# Traduction:  il se peut que je peux partir
#
#
# c= 15
# Anglais   :  the window was open
# Français  :  la fenetre etait ouverte
# Traduction:  la fenetre etait en ouverte
#
#
# c= 16
# Anglais   :  tom is going to enjoy it
# Français  :  tom aimera ca
# Traduction:  tom va travailler comme seul
#
#
# c= 17
# Anglais   :  it s not why i m here
# Français  :  ce n est pas ma raison d etre ici
# Traduction:  ce n est pas a je pourquoi pourquoi
#
#
# c= 18
# Anglais   :  i m not at all hungry
# Français  :  je n ai pas faim du tout
# Traduction:  je ne suis pas du tout faim
#
#
# c= 19
# Anglais   :  we have to stop
# Français  :  nous devons arreter
# Traduction:  nous devons l arreter
#
#
# c= 20
# Anglais   :  what s their story
# Français  :  quelle est leur histoire
# Traduction:  quelle est leur leur douleur
#
#
# c= 21
# Anglais   :  we have some time
# Français  :  nous avons un peu de temps
# Traduction:  nous avons beaucoup de temps
#
#
# c= 22
# Anglais   :  how can this be
# Français  :  comment cela se peut il
# Traduction:  comment cela peut il
#
#
# c= 23
# Anglais   :  we have no school today
# Français  :  nous n avons pas cours aujourd hui
# Traduction:  nous n avons pas ecole aujourd hui
#
#
# c= 24
# Anglais   :  words failed me
# Français  :  les mots me manquerent
# Traduction:  sans mes araignees
#
#
# c= 25
# Anglais   :  stop crying like a girl
# Français  :  arrete de pleurer comme une fille
# Traduction:  arretez de pleurer comme une fille
#
#
# c= 26
# Anglais   :  the week is finally over
# Français  :  la semaine est enfin terminee
# Traduction:  la pauvre prochaine etait trop
#
#
# c= 27
# Anglais   :  forgive me for being late
# Français  :  veuillez m excuser pour mon retard
# Traduction:  moi moi moi en retard
#
#
# c= 28
# Anglais   :  you can t go out
# Français  :  tu ne peux pas sortir
# Traduction:  tu ne peux pas sortir
#
#
# c= 29
# Anglais   :  he was scared to do it
# Français  :  il avait peur de le faire
# Traduction:  il n a pas le de faire beaucoup
#
#
# c= 30
# Anglais   :  how much time did we lose
# Français  :  combien de temps a t on perdu
# Traduction:  combien de temps avons nous perdu
#
#
# c= 31
# Anglais   :  i use it every day
# Français  :  je l utilise tous les jours
# Traduction:  je le le le train train d acheter des
#
#
# c= 32
# Anglais   :  he succeeded in business
# Français  :  il eut du succes en affaires
# Traduction:  il a eu du succes pour les
#
#
# c= 33
# Anglais   :  we re confident
# Français  :  nous avons confiance
# Traduction:  nous sommes confiants
#
#
# c= 34
# Anglais   :  can anyone drive
# Français  :  quiconque sait il conduire
# Traduction:  est ce que il te
#
#
# c= 35
# Anglais   :  i m going to build a fire
# Français  :  je vais faire un feu
# Traduction:  je vais confectionner un bucher
#
#
# c= 36
# Anglais   :  how re you doing
# Français  :  comment vas tu
# Traduction:  comment allez vous
#
#
# c= 37
# Anglais   :  i m just not sure
# Français  :  je n en suis simplement pas sure
# Traduction:  je ne suis pas simplement pas sur
#
#
# c= 38
# Anglais   :  i am acting for my father
# Français  :  j agis pour mon pere
# Traduction:  je ai beaucoup de peu sur mon conseil
#
#
# c= 39
# Anglais   :  come if you can
# Français  :  viens si tu peux
# Traduction:  venez si tu pouvez
#
#
# c= 40
# Anglais   :  our hotel faces the coast
# Français  :  notre hotel donne sur la cote
# Traduction:  son espoir a ferme ses paroles a la
#
#
# c= 41
# Anglais   :  will you join us
# Français  :  vous joindrez vous a nous
# Traduction:  allez vous joindre a nous
#
#
# c= 42
# Anglais   :  it was fabulous
# Français  :  ca a ete fabuleux
# Traduction:  ce fut fabuleux
#
#
# c= 43
# Anglais   :  come meet everybody
# Français  :  viens rencontrer tout le monde
# Traduction:  tout le tout monde se trouve
#
#
# c= 44
# Anglais   :  your sister is attractive
# Français  :  ta sur est attirante
# Traduction:  votre sur est attirante
#
#
# c= 45
# Anglais   :  you need to relax
# Français  :  vous devez vous detendre
# Traduction:  tu dois faut vous detendre
#
#
# c= 46
# Anglais   :  i m not paid to do that
# Français  :  je ne suis pas paye pour faire cela
# Traduction:  je ne suis pas payee pour faire cela
#
#
# c= 47
# Anglais   :  this is how it works
# Français  :  c est comme ca que cela fonctionne
# Traduction:  c est ainsi le faire
#
#
# c= 48
# Anglais   :  i emptied the dishwasher
# Français  :  j ai vide le lave vaisselle
# Traduction:  j ai le contrat
#
#
# c= 49
# Anglais   :  what s going on here
# Français  :  que se passe t il ici
# Traduction:  que se passe t il ici
#
#
# c= 50
# Anglais   :  you re pretty good
# Français  :  t es assez bon
# Traduction:  vous etes assez bonnes
#
#
# c= 51
# Anglais   :  i m touched
# Français  :  je suis touche
# Traduction:  je suis touchee
#
#
# c= 52
# Anglais   :  was anybody else there
# Français  :  qui que ce soit d autre s y trouvait il
# Traduction:  qui que ce soit etait il t il
#
#
# c= 53
# Anglais   :  i have cancer
# Français  :  j ai un cancer
# Traduction:  j ai dote d un cancer
#
#
# c= 54
# Anglais   :  they lost again
# Français  :  elles ont perdu a nouveau
# Traduction:  ils ont encore perdu
#
#
# c= 55
# Anglais   :  how much is this pen
# Français  :  combien coute ce stylo
# Traduction:  quel est le prix
#
#
# c= 56
# Anglais   :  tom is really ambitious
# Français  :  tom est tres ambitieux
# Traduction:  tom est vraiment ambitieux
#
#
# c= 57
# Anglais   :  watch the door
# Français  :  surveille la porte
# Traduction:  surveillez la porte
#
#
# c= 58
# Anglais   :  i m not a child
# Français  :  je ne suis pas une enfant
# Traduction:  je ne suis pas un enfant
#
#
# c= 59
# Anglais   :  the picnic lasted all day
# Français  :  le pique nique a dure toute la journee
# Traduction:  le voiture ne mange finalement pas la journee
#
#
# c= 60
# Anglais   :  whose book is this
# Français  :  a qui appartient ce livre
# Traduction:  a qui est ce livre
#
#
# c= 61
# Anglais   :  go with the flow
# Français  :  surfez sur la vague
# Traduction:  arrete de savoir
#
#
# c= 62
# Anglais   :  i feel like i know you
# Français  :  j ai le sentiment de vous connaitre
# Traduction:  j ai envie de te je te
#
#
# c= 63
# Anglais   :  he pushed me gently
# Français  :  il me poussa gentiment
# Traduction:  il m a pousse gentiment
#
#
# c= 64
# Anglais   :  you re standing in my way
# Français  :  vous vous tenez sur mon chemin
# Traduction:  vous allez corriger dans ma chambre
#
#
# c= 65
# Anglais   :  there isn t any solution
# Français  :  il n y a aucune solution
# Traduction:  il n y a personne
#
#
# c= 66
# Anglais   :  gambling is a curse
# Français  :  le jeu est une malediction
# Traduction:  sa voiture est une ford
#
#
# c= 67
# Anglais   :  is this seat vacant
# Français  :  est ce que ce siege est libre
# Traduction:  cette place est elle libre
#
#
# c= 68
# Anglais   :  tom didn t mean it
# Français  :  tom ne voulait pas dire ca
# Traduction:  tom n a pas pas
#
#
# c= 69
# Anglais   :  he taught me how to drive
# Français  :  il m a appris a conduire
# Traduction:  il m a apporte volontiers
#
#
# c= 70
# Anglais   :  i m crazy about you
# Français  :  je suis fou de toi
# Traduction:  je suis en de vous
#
#
# c= 71
# Anglais   :  go up the stairs
# Français  :  prenez les escaliers
# Traduction:  ont ils le le
#
#
# c= 72
# Anglais   :  it should be no problem
# Français  :  ca ne devrait pas etre un probleme
# Traduction:  ca ne devrais pas prendre un probleme
#
#
# c= 73
# Anglais   :  our guests have arrived
# Français  :  nos invites sont arrives
# Traduction:  nos invitees sont arrivees
#
#
# c= 74
# Anglais   :  this is my notebook
# Français  :  c est mon ordinateur portable
# Traduction:  c est mon carnet de notes
#
#
# c= 75
# Anglais   :  when is good for you
# Français  :  quand cela te convient il
# Traduction:  quand est ce que vous vous en
#
#
# c= 76
# Anglais   :  you re very rude
# Français  :  vous etes fort grossieres
# Traduction:  tu es tres grossier
#
#
# c= 77
# Anglais   :  i love a challenge
# Français  :  j adore les defis
# Traduction:  j ai un defi defi
#
#
# c= 78
# Anglais   :  what size are these shoes
# Français  :  de quelle taille sont ces chaussures
# Traduction:  quelles sont les trois enfants
#
#
# c= 79
# Anglais   :  this is a coconut
# Français  :  c est une noix de coco
# Traduction:  ceci est un ordre
#
#
# c= 80
# Anglais   :  is anyone looking
# Français  :  qui que ce soit regarde t il
# Traduction:  quiconque est il en train de regarder
#
#
# c= 81
# Anglais   :  he s right behind you
# Français  :  il est juste derriere vous
# Traduction:  il est juste derriere toi
#
#
# c= 82
# Anglais   :  your name was mentioned
# Français  :  ton nom a ete mentionne
# Traduction:  votre reponse etait votre
#
#
# c= 83
# Anglais   :  i felt weak in the knees
# Français  :  j ai senti une faiblesse dans les genoux
# Traduction:  je me suis senti senti la
#
#
# c= 84
# Anglais   :  please give me an ashtray
# Français  :  donne moi un cendrier s il te plait
# Traduction:  donnez moi un cendrier s ils vous plait
#
#
# c= 85
# Anglais   :  we import tea from india
# Français  :  nous importons le the d inde
# Traduction:  nous avons fait de du meme intention
#
#
# c= 86
# Anglais   :  where is the bus schedule
# Français  :  ou sont les horaires de bus
# Traduction:  ou est est en bus
#
#
# c= 87
# Anglais   :  i had a cat named cookie
# Français  :  j ai eu un chat denomme biscuit
# Traduction:  j ai eu un chat par chat
#
#
# c= 88
# Anglais   :  she is powerful
# Français  :  elle est puissante
# Traduction:  elle est devenue
#
#
# c= 89
# Anglais   :  i thought it was true
# Français  :  je croyais que c etait vrai
# Traduction:  je pensais vraiment que ce soit termine
#
#
# c= 90
# Anglais   :  they found out
# Français  :  elles ont decouvert le truc
# Traduction:  ils ont decouvert le truc
#
#
# c= 91
# Anglais   :  they work for me
# Français  :  ils travaillent pour moi
# Traduction:  ils travaillent pour moi
#
#
# c= 92
# Anglais   :  we don t know the lyrics
# Français  :  nous ne connaissons pas les paroles
# Traduction:  nous ne le savons pas le
#
#
# c= 93
# Anglais   :  we lost
# Français  :  nous perdimes
# Traduction:  nous avons ete defaites
#
#
# c= 94
# Anglais   :  the situation worsened
# Français  :  la situation empira
# Traduction:  la situation a empire
#
#
# c= 95
# Anglais   :  he s extremely happy
# Français  :  il est extremement heureux
# Traduction:  il extremement creve
#
#
# c= 96
# Anglais   :  i ve always paid the rent
# Français  :  j ai toujours paye le loyer
# Traduction:  je pensais toujours vous le nez
#
#
# c= 97
# Anglais   :  i went there to meet him
# Français  :  je m y suis rendu pour le rencontrer
# Traduction:  je suis alle pour le pouvoir
#
#
# c= 98
# Anglais   :  i heard tom scream
# Français  :  j ai entendu tom crier
# Traduction:  j ai entendu ce qu il
#
#
# c= 99
# Anglais   :  the server is down again
# Français  :  le serveur est encore en panne
# Traduction:  le soleil s en en en endormi
#
#
# c= 100
# Anglais   :  i hate fanatics
# Français  :  j ai horreur des fanatiques
# Traduction:  je deteste les fanatiques
#
#
# c= 101
# Anglais   :  tell tom to shut up
# Français  :  dis a tom de la fermer
# Traduction:  dites a tom de se taire
#
#
# c= 102
# Anglais   :  i have a cat named cookie
# Français  :  j ai un chat qui s appelle cookie
# Traduction:  j ai un chat chat chat
#
#
# c= 103
# Anglais   :  we need to do this
# Français  :  nous avons besoin de faire ceci
# Traduction:  nous devons faire ceci
#
#
# c= 104
# Anglais   :  i m not deaf
# Français  :  je ne suis pas sourd
# Traduction:  je ne suis pas sourde
#
#
# c= 105
# Anglais   :  staying home isn t fun
# Français  :  rester chez soi n a rien d amusant
# Traduction:  rester soi soi n est pas marrant
#
#
# c= 106
# Anglais   :  it nearly cost me my life
# Français  :  ca m a presque coute la vie
# Traduction:  il avait du couter mon de mon monde
#
#
# c= 107
# Anglais   :  we re not barbarians
# Français  :  nous ne sommes pas des barbares
# Traduction:  nous ne sommes pas les deux
#
#
# c= 108
# Anglais   :  i d forgotten that
# Français  :  j avais oublie cela
# Traduction:  j en ferai
#
#
# c= 109
# Anglais   :  it s not enough
# Français  :  ca ne suffit pas
# Traduction:  ce n est pas suffisant
#
#
# c= 110
# Anglais   :  what do you need to know
# Français  :  qu avez vous besoin de savoir
# Traduction:  qu avez vous besoin de savoir
#
#
# c= 111
# Anglais   :  i got a bad grade
# Français  :  j ai eu une mauvaise note
# Traduction:  je suis suis tape une mauvaise note
#
#
# c= 112
# Anglais   :  the change was immediate
# Français  :  le changement fut immediat
# Traduction:  le changement etait ete
#
#
# c= 113
# Anglais   :  there is no water
# Français  :  il n y a pas d eau
# Traduction:  il n y a pas de l eau
#
#
# c= 114
# Anglais   :  you re very resourceful
# Français  :  vous etes plein de ressources
# Traduction:  vous es pleine de ressources
#
#
# c= 115
# Anglais   :  would you care to bet
# Français  :  voudriez vous parier
# Traduction:  voudrais tu parier
#
#
# c= 116
# Anglais   :  the snow stopped falling
# Français  :  la neige cessa de tomber
# Traduction:  le verre courut court court
#
#
# c= 117
# Anglais   :  he has a sweet voice
# Français  :  il a la voix douce
# Traduction:  il est d une vie
#
#
# c= 118
# Anglais   :  she lives next door to us
# Français  :  elle vit la porte a cote de la notre
# Traduction:  elle a tambourine pour nous la la
#
#
# c= 119
# Anglais   :  i ve lost my glasses
# Français  :  j ai perdu mes lunettes
# Traduction:  j ai des mes devoirs
#
#
# c= 120
# Anglais   :  are they new
# Français  :  sont ils neufs
# Traduction:  sont ils nouveaux
#
#
# c= 121
# Anglais   :  no one saw anything
# Français  :  personne n a rien vu
# Traduction:  personne ne vu quoi vu quoi
#
#
# c= 122
# Anglais   :  do you love me
# Français  :  m aimes tu
# Traduction:  est ce que
#
#
# c= 123
# Anglais   :  that girl looks boyish
# Français  :  cette fille ressemble a un garcon
# Traduction:  cette fille a l air d un garcon
#
#
# c= 124
# Anglais   :  i couldn t lie to you
# Français  :  je ne pouvais pas vous mentir
# Traduction:  je ne pourrais te mentir
#
#
# c= 125
# Anglais   :  i was completely shocked
# Français  :  j etais totalement sous le choc
# Traduction:  j etais totalement choque
#
#
# c= 126
# Anglais   :  let s ask the teacher
# Français  :  demandons a l instituteur
# Traduction:  demandons a l
#
#
# c= 127
# Anglais   :  can you drive a car
# Français  :  pouvez vous conduire une voiture
# Traduction:  savez vous conduire
#
#
# c= 128
# Anglais   :  she has good handwriting
# Français  :  elle a une belle ecriture
# Traduction:  elle est dotee d une belle ecriture
#
#
# c= 129
# Anglais   :  i m an agent
# Français  :  je suis un agent
# Traduction:  je suis un
#
#
# c= 130
# Anglais   :  did you hear the noise
# Français  :  as tu entendu ce bruit
# Traduction:  avez vous entendu ce mot
#
#
# c= 131
# Anglais   :  who are you talking with
# Français  :  avec qui parles tu
# Traduction:  avec qui parlez vous
#
#
# c= 132
# Anglais   :  i m horrible with kids
# Français  :  je suis terrible avec les enfants
# Traduction:  je suis horrible avec les gamins
#
#
# c= 133
# Anglais   :  you re my boss
# Français  :  tu es mon patron
# Traduction:  tu es ma patron
#
#
# c= 134
# Anglais   :  it is good to be a winner
# Français  :  c est bon d etre un gagneur
# Traduction:  c est un pour d etre
#
#
# c= 135
# Anglais   :  do you think so
# Français  :  penses tu la meme chose
# Traduction:  le penses tu
#
#
# c= 136
# Anglais   :  i love that movie
# Français  :  j adore ce film
# Traduction:  j adore le film
#
#
# c= 137
# Anglais   :  i m in shock right now
# Français  :  je suis sous le choc actuellement
# Traduction:  je suis en train de dire
#
#
# c= 138
# Anglais   :  i want the truth from you
# Français  :  je veux que tu me dises la verite
# Traduction:  je veux de vous la verite
#
#
# c= 139
# Anglais   :  you re lost
# Français  :  tu es perdue
# Traduction:  tu es perdu
#
#
# c= 140
# Anglais   :  please open your bag
# Français  :  s il vous plait ouvrez votre sac
# Traduction:  veuillez vous mot de retour
#
#
# c= 141
# Anglais   :  i went hiking
# Français  :  je suis partie en excursion
# Traduction:  j ai rendu l endormie
#
#
# c= 142
# Anglais   :  why is the light on
# Français  :  pourquoi la lumiere est elle allumee
# Traduction:  pourquoi le la est est ouverte
#
#
# c= 143
# Anglais   :  it was quite funny
# Français  :  c etait tout a fait amusant
# Traduction:  ce fut assez amusant
#
#
# c= 144
# Anglais   :  where s the station
# Français  :  ou est la gare
# Traduction:  ou se trouve la gare
#
#
# c= 145
# Anglais   :  i m still married
# Français  :  je suis encore mariee
# Traduction:  je suis toujours marie
#
#
# c= 146
# Anglais   :  you re out of time
# Français  :  ton temps est ecoule
# Traduction:  on est ecoule
#
#
# c= 147
# Anglais   :  how s your new job
# Français  :  cest comment ton nouveau boulot
# Traduction:  comment est ton nouvel
#
#
# c= 148
# Anglais   :  it wasn t an accident
# Français  :  ca n a pas ete un accident
# Traduction:  ce n etait pas un accident
#
#
# c= 149
# Anglais   :  is this normal behavior
# Français  :  est ce un comportement normal
# Traduction:  est ce une loin
#
#
# c= 150
# Anglais   :  don t smoke
# Français  :  ne fumez pas
# Traduction:  ne fume pas
#
#
# c= 151
# Anglais   :  take tom outside
# Français  :  emmene tom dehors
# Traduction:  emmenez tom dehors
#
#
# c= 152
# Anglais   :  i won t say anything
# Français  :  je ne dirai rien
# Traduction:  je ne dis rien dire
#
#
# c= 153
# Anglais   :  i caught her by the hand
# Français  :  je l ai attrapee par la main
# Traduction:  je l ai donne par les
#
#
# c= 154
# Anglais   :  she is crying
# Français  :  elle est en train de pleurer
# Traduction:  elle pleure
#
#
# c= 155
# Anglais   :  do you smell something
# Français  :  sens tu quelque chose
# Traduction:  sentez vous quelque chose
#
#
# c= 156
# Anglais   :  be respectful
# Français  :  sois respectueux
# Traduction:  soyez respectueuse
#
#
# c= 157
# Anglais   :  he may have told a lie
# Français  :  peut etre a t il menti
# Traduction:  il peut etre menti menti
#
#
# c= 158
# Anglais   :  are you relaxed
# Français  :  etes vous detendues
# Traduction:  es tu detendue
#
#
# c= 159
# Anglais   :  i m not one to gossip
# Français  :  je ne suis pas une commere
# Traduction:  je n suis pas pour pour faire
#
#
# c= 160
# Anglais   :  this is obviously fake
# Français  :  ceci est evidemment faux
# Traduction:  c est de toute evidence faux
#
#
# c= 161
# Anglais   :  tom is still outside
# Français  :  tom est toujours dehors
# Traduction:  tom ne toujours encore dehors
#
#
# c= 162
# Anglais   :  i m sorry
# Français  :  excuse moi
# Traduction:  desole
#
#
# c= 163
# Anglais   :  we have pictures
# Français  :  nous avons des photos
# Traduction:  nous avons de de
#
#
# c= 164
# Anglais   :  did you pass your exams
# Français  :  as tu reussi tes examens
# Traduction:  avez vous reussi vos examens
#
#
# c= 165
# Anglais   :  i took care of it myself
# Français  :  je m en suis occupe personnellement
# Traduction:  j m en pris d accord
#
#
# c= 166
# Anglais   :  you re opportunistic
# Français  :  vous etes un opportuniste
# Traduction:  vous es un opportuniste
#
#
# c= 167
# Anglais   :  i don t like dancing
# Français  :  je n aime pas danser
# Traduction:  je n aime pas les sciences
#
#
# c= 168
# Anglais   :  you re a woman now
# Français  :  tu es desormais une femme
# Traduction:  tu es desormais une femme
#
#
# c= 169
# Anglais   :  i m wide awake
# Français  :  je suis tout a fait eveillee
# Traduction:  je pense que vous est tout
#
#
# c= 170
# Anglais   :  he is good at singing
# Français  :  il chante bien
# Traduction:  il est bon chanteur
#
#
# c= 171
# Anglais   :  tom is a slow walker
# Français  :  tom marche lentement
# Traduction:  tom est un drole de terre
#
#
# c= 172
# Anglais   :  i bet you know french
# Français  :  je parie que tu connais le francais
# Traduction:  je parie que vous vous toutes
#
#
# c= 173
# Anglais   :  i m in training
# Français  :  je suis en formation
# Traduction:  je suis presque
#
#
# c= 174
# Anglais   :  i hope you re happy
# Français  :  j espere que tu es heureux
# Traduction:  j espere que vous etes heureux
#
#
# c= 175
# Anglais   :  she has a picture
# Français  :  elle dispose d une photo
# Traduction:  elle detient une photo
#
#
# c= 176
# Anglais   :  let s dance shall we
# Français  :  dansons veux tu
# Traduction:  dansons voulez vous
#
#
# c= 177
# Anglais   :  fill out this form
# Français  :  remplis ce formulaire
# Traduction:  remplissez ce formulaire
#
#
# c= 178
# Anglais   :  i ll find a way
# Français  :  je trouverai un moyen
# Traduction:  je trouverai un bon
#
#
# c= 179
# Anglais   :  show us the room
# Français  :  montrez nous la piece
# Traduction:  montre nous la chambre
#
#
# c= 180
# Anglais   :  i had a vision
# Français  :  j ai eu une vision
# Traduction:  j ai fait des
#
#
# c= 181
# Anglais   :  she is no match for me
# Français  :  elle n est pas de taille avec moi
# Traduction:  elle n a pas fait de velo
#
#
# c= 182
# Anglais   :  are they new
# Français  :  sont elles nouvelles
# Traduction:  sont ils nouveaux
#
#
# c= 183
# Anglais   :  it s not ridiculous
# Français  :  ce n est pas ridicule
# Traduction:  ce n est pas ridicule
#
#
# c= 184
# Anglais   :  i have my passport
# Français  :  j ai mon passeport
# Traduction:  j ai claque ma
#
#
# c= 185
# Anglais   :  hand it over
# Français  :  remets le
# Traduction:  remettez le
#
#
# c= 186
# Anglais   :  come over to my place
# Français  :  viens chez moi
# Traduction:  a moi la
#
#
# c= 187
# Anglais   :  no one was satisfied
# Français  :  personne ne fut satisfait
# Traduction:  personne ne etait satisfait
#
#
# c= 188
# Anglais   :  i can t agree with you
# Français  :  je ne peux pas etre d accord avec toi
# Traduction:  je ne peux pas etre sur avec toi
#
#
# c= 189
# Anglais   :  we have no choice
# Français  :  nous n avons pas le choix
# Traduction:  nous ne avons pas le choix
#
#
# c= 190
# Anglais   :  let me see that
# Français  :  fais moi voir ca
# Traduction:  montrez moi ca
#
#
# c= 191
# Anglais   :  that s not an option
# Français  :  ca ne constitue pas une option
# Traduction:  ce n est pas une affaire
#
#
# c= 192
# Anglais   :  did you hear that
# Français  :  avez vous entendu cela
# Traduction:  as tu entendu cela
#
#
# c= 193
# Anglais   :  take as many as you want
# Français  :  prenez en autant que vous voulez
# Traduction:  prenez en autant que vous voulez
#
#
# c= 194
# Anglais   :  why does tom want my help
# Français  :  pourquoi tom desire t il mon aide
# Traduction:  pourquoi tom a t il trouve
#
#
# c= 195
# Anglais   :  i can t let them catch me
# Français  :  je ne peux les laisser m attraper
# Traduction:  je ne peux pas m echapper
#
#
# c= 196
# Anglais   :  i did it for you
# Français  :  je le fis pour vous
# Traduction:  je le fis pour toi
#
#
# c= 197
# Anglais   :  are you actually serious
# Français  :  es tu vraiment serieuse
# Traduction:  es tu vraiment serieux
#
#
# c= 198
# Anglais   :  that s blackmail
# Français  :  c est du chantage
# Traduction:  c est faux
#
#
# c= 199
# Anglais   :  i can t go with you
# Français  :  je ne peux pas partir avec toi
# Traduction:  je ne peux pas me avec avec vous
#
#
# c= 200
# Anglais   :  may i go
# Français  :  puis je y aller
# Traduction:  puis je partir
#
#
# c= 201
# Anglais   :  let me call my lawyer
# Français  :  laisse moi appeler mon avocat
# Traduction:  arrete de mon appeler mon aide
#
#
# c= 202
# Anglais   :  i just want some answers
# Français  :  je veux juste des reponses
# Traduction:  je veux simplement disparaitre
#
#
# c= 203
# Anglais   :  nobody wants it
# Français  :  personne ne le veut
# Traduction:  personne ne le veut
#
#
# c= 204
# Anglais   :  is anyone else home
# Français  :  qui que ce soit d autre se trouve t il dans la maison
# Traduction:  qui que ce soit est il t il il
#
#
# c= 205
# Anglais   :  i overslept yesterday
# Français  :  je n ai pas entendu le reveil hier
# Traduction:  je n avais avais aucun a des voix
#
#
# c= 206
# Anglais   :  i m studying very hard
# Français  :  j etudie avec beaucoup d assiduite
# Traduction:  j etudie tres consciencieusement
#
#
# c= 207
# Anglais   :  i am sorry for you
# Français  :  je suis desole pour toi
# Traduction:  je suis desolee pour vous
#
#
# c= 208
# Anglais   :  do you talk to your cats
# Français  :  parlez vous a vos chats
# Traduction:  parles tu a votre chats
#
#
# c= 209
# Anglais   :  what is your emergency
# Français  :  quelle est votre urgence
# Traduction:  quelle est ta urgence urgence
#
#
# c= 210
# Anglais   :  let s not talk to her
# Français  :  ne lui parlons pas
# Traduction:  ne parlons pas de cette
#
#
# c= 211
# Anglais   :  was it all worth it
# Français  :  est ce que ca en valait la peine
# Traduction:  le valait lui peine le
#
#
# c= 212
# Anglais   :  she dressed like a boy
# Français  :  elle s est habillee comme un garcon
# Traduction:  elle a un grand aide
#
#
# c= 213
# Anglais   :  you seemed to like that
# Français  :  tu as semble l apprecier
# Traduction:  tu as a l apprecier l apprecier
#
#
# c= 214
# Anglais   :  this chair is too small
# Français  :  cette chaise est trop petite
# Traduction:  cette chaise est trop eleve
#
#
# c= 215
# Anglais   :  wait a minute
# Français  :  un instant
# Traduction:  attends une minute
#
#
# c= 216
# Anglais   :  just get out of here
# Français  :  degagez simplement d ici
# Traduction:  degage simplement d ici
#
#
# c= 217
# Anglais   :  let s not panic
# Français  :  ne paniquons pas
# Traduction:  ne bouge pas
#
#
# c= 218
# Anglais   :  tom lowered his sword
# Français  :  tom a abaisse son epee
# Traduction:  tom degaina son son son
#
#
# c= 219
# Anglais   :  i feel normal
# Français  :  je me sens normale
# Traduction:  je me sens normal
#
#
# c= 220
# Anglais   :  she can t stop me
# Français  :  elle ne peut pas m arreter
# Traduction:  elle ne peut pas me arreter
#
#
# c= 221
# Anglais   :  that was all greek to me
# Français  :  ca c etait du javanais pour moi
# Traduction:  c etait plutot a pour chinois pour moi
#
#
# c= 222
# Anglais   :  you are gorgeous
# Français  :  tu es splendide
# Traduction:  vous etes splendide
#
#
# c= 223
# Anglais   :  you can have both
# Français  :  tu peux avoir les deux
# Traduction:  tu peux avoir les deux
#
#
# c= 224
# Anglais   :  the door remained closed
# Français  :  la porte resta fermee
# Traduction:  la porte resta restee restee
#
#
# c= 225
# Anglais   :  he died last year
# Français  :  il est mort l annee derniere
# Traduction:  il est mort d annee derniere
#
#
# c= 226
# Anglais   :  we love each other
# Français  :  nous nous aimons l un l autre
# Traduction:  nous nous sommes a vus
#
#
# c= 227
# Anglais   :  this door s locked
# Français  :  cette porte est verrouillee
# Traduction:  cette caisse est change
